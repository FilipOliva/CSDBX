-- %%
------------------------------------------------------------------------------------------------------
select * from gap_catalog.ads_etl_owner.XC_SMA_CASE_PHASE_PROPERTIES_POT_OWN
where CPPROP_KEY is not null;

select count(1) from gap_catalog.ads_owner.DIFF_ADS_SMA_CASE_PHASE_PROPERTIES_POT_OWN_ADS_MAP_SCD_DIFF;

------------------------------------------------------------------------------------------------------
select count(1) from gap_catalog.ads_etl_owner.STG_SMA_CASE_PHASE_PROPERTIES_HUMANTASK;

select count(1) from  gap_catalog.ads_owner.DIFF_ADS_SMA_CASE_PHASE_PROPERTIES_HUMANTASK_ADS_MAP_SCD_DIFF;

select count(1) from gap_catalog.ads_etl_owner.XC_SMA_CASE_PHASE_PROPERTIES_HUMANTASK;

CALL gap_catalog.ads_etl_owner.sp_ADS_SMA_CASE_PHASE_PROPERTIES_HUMANTASK(
    '2025-09-01', 
    -888
);

------------------------------------------------------------------------------------------------------
CALL gap_catalog.ads_etl_owner.sp_ADS_SMA_CASE_PHASE_PROPERTIES_MAIN_BUSY_BANKING(
    '2025-09-01', 
    -888
);

select count(1) from gap_catalog.ads_etl_owner.XC_ADS_SMA_CASE_PHASE_PROPERTIES_MAIN_BUSY_BANKING;

select * from gap_catalog.ads_owner.DIFF_ADS_SMA_CASE_PHASE_PROPERTIES_MAIN_BUSY_BANKING_ADS_MAP_SCD_DIFF
;

select tech_new_rec,count (1) from gap_catalog.ads_owner.DIFF_ADS_SMA_CASE_PHASE_PROPERTIES_MAIN_BUSY_BANKING_ADS_MAP_SCD_DIFF
group by tech_new_rec;
------------------------------------------------------------------------------------------------------
CALL gap_catalog.ads_etl_owner.sp_ADS_SMA_CASE_PHASE_PROPERTIES_MAIN(
    '2025-09-01', 
    -888
);

select 
count(1) from gap_catalog.ads_etl_owner.XC_SMA_CASE_PHASE_PROPERTIES_MAIN;

21.188.300.096


select count(1) from gap_catalog.ads_owner.SMA_CASE_PHASE_PROPERTIES;
43.572.663

select *
from
gap_catalog.ads_owner.DIFF_ADS_SMA_CASE_PHASE_PROPERTIES_MAIN_ADS_MAP_SCD_DIFF
;

select tech_new_rec, count(1)
from
gap_catalog.ads_owner.DIFF_ADS_SMA_CASE_PHASE_PROPERTIES_MAIN_ADS_MAP_SCD_DIFF
group by tech_new_rec;


DROP TABLE IF EXISTS gap_catalog.ads_owner.DIFF_ADS_SMA_CASE_PHASE_PROPERTIES_MAIN_ADS_MAP_SCD_DIFF;

create table gap_catalog.ads_owner.DIFF_ADS_SMA_CASE_PHASE_PROPERTIES_MAIN_ADS_MAP_SCD_DIFF
( tech_del_flg  char(1),
  tech_new_rec  char(1),
  tech_rid      varchar(255),
  CPPROP_KEY  BIGINT,
  --CPPROP_KEY_NEW BIGINT GENERATED ALWAYS AS IDENTITY (START WITH ' || max_key ||' INCREMENT BY 1),
  CPPROP_SOURCE_ID  varchar(400),
  CPPROP_SOURCE_SYSTEM_ID  varchar(120),
  CPPROP_SOURCE_SYS_ORIGIN  varchar(120),
  CPPROP_PARENT_KEY  BIGINT,
  CASEPH_KEY  BIGINT,
  CPPTP_KEY  BIGINT,
  CTP_KEY  BIGINT,
  CASE_KEY  BIGINT,
  CASE_START_DATE  DATE,
  CPPROP_VALUE_TEXT  varchar(4000),
  CPPROP_VALUE_DATE  DATE,
  CPPROP_VALUE_NUMBER  DOUBLE,
  CPPRV_KEY  BIGINT)
  USING DELTA
TBLPROPERTIES (
  'delta.autoOptimize.optimizeWrite' = 'true',
  'delta.autoOptimize.autoCompact' = 'true'
);

ALTER TABLE 
--gap_catalog.ads_etl_owner.XC_SMA_CASE_PHASE_PROPERTIES_MAIN
 gap_catalog.ADS_ETL_OWNER.XC_SMA_PROCESS_EVENTS_MAIN
SET TBLPROPERTIES (
  'delta.autoOptimize.optimizeWrite' = 'true'
  --,'delta.autoOptimize.autoCompact' = 'true'
);
