-- %%
CREATE TABLE IF NOT EXISTS gap_catalog.ads_owner.dlk_ads_lov_rds_sendnotificationstatus DEEP CLONE
gap_catalog.ads_src_20250901.dlk_ads_lov_rds_sendnotificationstatus;

CREATE TABLE IF NOT EXISTS gap_catalog.ads_owner.dlk_ads_lov_rds_identityregistrationcasestates
DEEP CLONE gap_catalog.ads_src_20250901.dlk_ads_lov_rds_identityregistrationcasestates;

CREATE TABLE IF NOT EXISTS gap_catalog.ads_owner.dlk_ads_lov_rds_distrainteventtype DEEP CLONE
gap_catalog.ads_src_20250901.dlk_ads_lov_rds_distrainteventtype;

CREATE TABLE IF NOT EXISTS gap_catalog.ads_owner.dlk_ads_lov_rds_personidentificationstate
DEEP CLONE gap_catalog.ads_src_20250901.dlk_ads_lov_rds_personidentificationstate;

CREATE TABLE IF NOT EXISTS gap_catalog.ads_owner.dlk_ads_rds_onboardingeligibilitycheckresult
DEEP CLONE gap_catalog.ads_src_20250901.dlk_ads_rds_onboardingeligibilitycheckresult;

CREATE TABLE IF NOT EXISTS gap_catalog.ads_owner.dlk_ads_lov_rds_identityregistrationaction
DEEP CLONE gap_catalog.ads_src_20250901.dlk_ads_lov_rds_identityregistrationaction;

CREATE TABLE IF NOT EXISTS gap_catalog.ads_owner.case_object_status DEEP CLONE
gap_catalog.ads_src_20250901.case_object_status;

CREATE TABLE IF NOT EXISTS gap_catalog.ads_owner.dlk_ads_lov_rds_mepoperationstate DEEP CLONE
gap_catalog.ads_src_20250901.dlk_ads_lov_rds_mepoperationstate;

CREATE TABLE IF NOT EXISTS gap_catalog.ads_owner.dlk_ads_lov_rds_conditionfulfillmentevent
DEEP CLONE gap_catalog.ads_src_20250901.dlk_ads_lov_rds_conditionfulfillmentevent;

CREATE TABLE IF NOT EXISTS gap_catalog.ads_owner.case_types DEEP CLONE
gap_catalog.ads_src_20250901.case_types;

CREATE TABLE IF NOT EXISTS gap_catalog.ads_owner.case_status DEEP CLONE
gap_catalog.ads_src_20250901.case_status;

CREATE TABLE IF NOT EXISTS gap_catalog.ads_owner.dlk_ads_lov_rds_analyticaleventtypes DEEP CLONE
gap_catalog.ads_src_20250901.dlk_ads_lov_rds_analyticaleventtypes;

CREATE TABLE IF NOT EXISTS gap_catalog.ads_owner.event_types DEEP CLONE
gap_catalog.ads_src_20250901.event_types;

CREATE TABLE IF NOT EXISTS gap_catalog.ads_owner.dlk_ads_lov_rds_humantaskeventtype DEEP CLONE
gap_catalog.ads_src_20250901.dlk_ads_lov_rds_humantaskeventtype;

CREATE TABLE IF NOT EXISTS gap_catalog.ads_owner.dlk_ads_lov_rds_dispotransactiontype DEEP CLONE
gap_catalog.ads_src_20250901.dlk_ads_lov_rds_dispotransactiontype;

CREATE TABLE IF NOT EXISTS gap_catalog.ads_owner.dlk_ads_rds_onboardingproductresult DEEP CLONE
gap_catalog.ads_src_20250901.dlk_ads_rds_onboardingproductresult;

CREATE TABLE IF NOT EXISTS gap_catalog.ads_owner.dlk_ads_rds_onboardingprocessstate DEEP CLONE
gap_catalog.ads_src_20250901.dlk_ads_rds_onboardingprocessstate;

CREATE TABLE IF NOT EXISTS gap_catalog.ads_owner.case_phase_property_types DEEP CLONE
gap_catalog.ads_src_20250901.case_phase_property_types;

CREATE TABLE IF NOT EXISTS gap_catalog.ads_owner.dlk_ads_lov_rds_distraintacttype DEEP CLONE
gap_catalog.ads_src_20250901.dlk_ads_lov_rds_distraintacttype;

CREATE TABLE IF NOT EXISTS gap_catalog.ads_owner.dlk_ads_lov_rds_analyticaleventstatus DEEP CLONE
gap_catalog.ads_src_20250901.dlk_ads_lov_rds_analyticaleventstatus;

CREATE TABLE IF NOT EXISTS gap_catalog.ads_owner.dlk_ads_lov_rds_distraintactstate DEEP CLONE
gap_catalog.ads_src_20250901.dlk_ads_lov_rds_distraintactstate;

CREATE TABLE IF NOT EXISTS gap_catalog.ads_owner.dlk_ads_lov_rds_distraintstate DEEP CLONE
gap_catalog.ads_src_20250901.dlk_ads_lov_rds_distraintstate;

CREATE TABLE IF NOT EXISTS gap_catalog.ads_owner.event_status DEEP CLONE
gap_catalog.ads_src_20250901.event_status;

CREATE TABLE IF NOT EXISTS gap_catalog.ads_owner.dlk_ads_rds_onboardingprocessresult DEEP CLONE
gap_catalog.ads_src_20250901.dlk_ads_rds_onboardingprocessresult;

CREATE TABLE IF NOT EXISTS gap_catalog.ads_owner.dlk_ads_lov_rds_errormessagebs DEEP CLONE
gap_catalog.ads_src_20250901.dlk_ads_lov_rds_errormessagebs;

CREATE TABLE IF NOT EXISTS gap_catalog.ads_owner.dlk_ads_lov_rds_mepoperationtype DEEP CLONE
gap_catalog.ads_src_20250901.dlk_ads_lov_rds_mepoperationtype;

CREATE TABLE IF NOT EXISTS gap_catalog.ads_owner.dlk_ads_lov_rds_identificationaction DEEP CLONE
gap_catalog.ads_src_20250901.dlk_ads_lov_rds_identificationaction;

CREATE TABLE IF NOT EXISTS gap_catalog.ads_owner.status_reason DEEP CLONE
gap_catalog.ads_src_20250901.status_reason;

CREATE TABLE IF NOT EXISTS gap_catalog.ads_owner.event_types_src DEEP CLONE
gap_catalog.ads_src_20250901.event_types_src;

CREATE TABLE IF NOT EXISTS gap_catalog.ads_owner.dlk_ads_rds_onboardingidentificationresult
DEEP CLONE gap_catalog.ads_src_20250901.dlk_ads_rds_onboardingidentificationresult;
